# %% [markdown]
# # 项目：可视化帕默群岛企鹅数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析报告的目的是对帕默群岛上企鹅样本的相关变量进行可视化，从而探索和分析种类、性别、所在岛屿等因素，与企鹅的身体属性，包括体重、嘴峰长度和深度、鳍的长度，之间的关系。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据`Penguins.csv`包括334个收集自南极洲帕尔默群岛的3个岛屿上的企鹅样本，以及企鹅相关属性数据，包括种类名、所在岛、嘴峰长度、嘴峰深度、鳍长度、体重、性别。
#
# `Penguins.csv`每列的含义如下：
# - species：企鹅的种类
# - island：企鹅所在岛
# - culmen_length_mm：企鹅嘴峰的长度（单位为毫米）
# - culmen_depth_mm：企鹅嘴峰的深度（单位为毫米）
# - flipper_length_mm：企鹅鳍的长度（单位为毫米）
# - body_mass_g：企鹅体重（单位为克）
# - sex：企鹅性别

# %% [markdown]
# ## 读取数据

# %% [markdown]
# 导入数据分析所需要的库，并通过Pandas的`read_csv函数`，将原始数据文件`Penguins.csv`里的数据内容，解析为DataFrame并赋值给变量`original_data`。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_data =pd.read_csv('penguins.csv')
original_data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ## 评估和清理数据

# %% [markdown]
# 该部分将对`original_data`DataFrame所包含的数据进行评估和清理。
#
# 主要分为两大类：结构+内容
#
# 数据的结构性问题指不符合“每个变量为一列，每个观察值为一行，每种类型的观察单位为一个表格”这三个标准；数据的内容性问题包括存在丢失数据、重复数据、无效数据等。

# %%
cleaned_data=original_data.copy()

# %% [markdown]
# ### 数据整齐度

# %%
cleaned_data.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# ...

# %% [markdown]
# 从前10行来看，数据满足“每个变量为一列，每个观察值为一行，每种类型的观察单位为一个表格”这三个标准，因此不存在结构性问题。

# %% [markdown]
# ### 数据干净度

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# 从输出结果来看。`cleaned_data`数据共有344条观察值，`culmen_length_mm `、`culmen_depth_mm`、`flipper_length_mm`、`body_mass_g `、`sex`变量存在缺失值，将在后续进行评估和清理。
#
# 调整数据类型，`species`、`sex`、`island`都是分类数据，因此可以把数据类型都转换为Category。

# %% [markdown]
# #### 处理缺失数值

# %%
cleaned_data.query('culmen_length_mm.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
cleaned_data.query('culmen_depth_mm.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
cleaned_data.query('flipper_length_mm.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
cleaned_data.query('body_mass_g.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
cleaned_data.query('sex.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# ...

# %% [markdown]
# 以上，可以观察到索引为3和339的观察值是除了种类和所属岛屿外所有变量都为空缺值，无法为探索企鹅身体属性相关因素提供价值，因此删除这两行

# %%
cleaned_data.drop([3,339],inplace=True)

# %%
cleaned_data.query('sex.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
#
#      body_mass_g  sex
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN

# %% [markdown]
# 缺失性别变量的观察值具备其他数据，仍可以为分析提供价值。由于Pandas以及Matplotlib、Seaborn会自动忽略缺失值，可保留这些行。

# %% [markdown]
# #### 处理重复数据

# %% [markdown]
# 不一致数据可能存在于所有分类变量中，要查看是否存在不同值实际值指代同一目标的情况。

# %%
cleaned_data['species'].value_counts()
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
cleaned_data['island'].value_counts()
# Out:
# island
# Biscoe       167
# Dream        124
# Torgersen     51
# Name: count, dtype: int64

# %%
cleaned_data['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %% [markdown]
# 从以上输出可以发现，`species`、`island`列里不存在不一致数据，而`sex`列里却存在一个英文句号值，并不代表任何有效性别，我们应把该值替换为NaN空值。

# %%
cleaned_data['sex'] = cleaned_data['sex'].replace(".", np.nan)

# %% [markdown]
# 查看是否修改成功

# %%
cleaned_data['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %% [markdown]
# #### 处理无效或错误数据

# %% [markdown]
# 可以通过DataFrame的describe方法，对数值统计信息进行快速了解。

# %%
cleaned_data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# 从以上信息来看，不存在脱离现实意义的数值。

# %% [markdown]
# ## 探索数据

# %% [markdown]
# 通过数据可视化，进行探索和分析，从图表中获得企鹅样本数据的相关洞察。

# %%
cleaned_data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
#设置色盘
sns.set_palette("pastel")

# %% [markdown]
# ### 企鹅种类比例

# %%
species_count=plt.pie(cleaned_data['species'].value_counts(),labels=cleaned_data['species'].value_counts().index,autopct='%.0f%%')
plt.show()
#太冗长了
#建议重新赋值 species_count=cleaned_data['spsecies'].value_counts()

# %% [markdown]
# 样本中`Adelie`占比最大，`Gentoo`种类的占比次之，`Chinstrap`的占比最小。

# %% [markdown]
# ### 企鹅所属岛屿比例

# %%
#老是粗心忘记加（）
island_count=cleaned_data['island'].value_counts()
plt.pie(island_count,labels=island_count.index,autopct="%.0f%%")
plt.show()

# %% [markdown]
# .index是属性 不带括号
# .value_counts是方法，要执行，带括号

# %% [markdown]
# 样本中一半左右的企鹅样本都来自`Biscoe`岛屿，占比最大，其次是`Drmeam`岛屿，来自`Torgersen`岛屿的样本最少。

# %% [markdown]
# ### 企鹅性别比例

# %%
sex_count=cleaned_data['sex'].value_counts()
plt.pie(sex_count,labels=sex_count.index,autopct="%.0f%%")
plt.show()

# %% [markdown]
# 样本企鹅性别占比持平，符合随机取样。

# %% [markdown]
# ### 不同岛上的企鹅种类数量

# %%
sns.countplot(cleaned_data,x='island',hue='species')
plt.show()

# %% [markdown]
# 从以上可看出，`Adelie`种类的企鹅样本在`Biscoe`,`Dream`,`Torgersen`这三个岛上都有分布，而`Chinstrap`种类只在`Dream`有分布，`Gentoo`只有Biscoe岛上有。

# %% [markdown]
# ### 不同岛屿上的企鹅性别数量

# %%
sns.countplot(cleaned_data,x="island",hue="sex")
plt.show()

# %% [markdown]
# ### 查看数值之间的相关关系

# %%
sns.pairplot(cleaned_data)
plt.show()

# %% [markdown]
# 从直方图来看。企鹅样本的嘴峰长度、嘴峰深度、鳍长度、体重的分布不是正态分布。一方面说明，这里面可能包含了许多组存在差异的样本数据，另一方面也说明样本数不够大。
#
# 另外可以在散点图中可以看出明显的多个集群，可能与某些因素有关，比如企鹅的种类、性别，因此可以对对比进行进一步的分类。

# %% [markdown]
# #### 根据种类查看数值之间的相关关系

# %%
sns.pairplot(cleaned_data,hue='species')
plt.show()

# %% [markdown]
# 从各个散点图可观察到同一种类的企鹅样本数据基本聚在一起，说明同一种类的企鹅在嘴峰长度、嘴峰深度、鳍长度、体重之间关系上，存在相似性。这些发现有利于我们根据体重、鳍长等数值推断企鹅的种类，也可以根据企鹅种类推测体重、鳍长的数值。

# %%
sns.pairplot(cleaned_data,hue='species',kind="reg",plot_kws={"scatter_kws":{'alpha':0.3}})
plt.show()

# %% [markdown]
# 散点图结合线性回归线来看，同类企鹅的属性数据之间均呈线性正比，既嘴峰越长，嘴峰越深，鳍越长，体重越重，嘴峰越短，鳍越短，体重越轻。
#
# 从密度分析图来看，可以得到以下关于样本的发现：
#
# * Chinstrap和Gentoo的嘴峰长度范围较为接近，而Adelie的嘴峰长度最短。
# * Adelie和Chintrap的嘴峰深度范围较为接近，而Gentoo的嘴锋深度最短。
# * Adelie的鳍长度最短，Chinstrap中等，而Gentoo的鳍长度最长。
# * Adelie和Chinstrap的体重范围较为接近，而Gentoo的体重最大。
